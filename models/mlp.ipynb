# %%
import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler 
from sklearn.impute import SimpleImputer 
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read Train Data

# %%
# Read training inputs
train_home_team_statistics_df = pd.read_csv('../Train_Data/train_home_team_statistics_df.csv', index_col=0)
train_away_team_statistics_df = pd.read_csv('../Train_Data/train_away_team_statistics_df.csv', index_col=0)

# Read training labels
train_labels = pd.read_csv('../Train_Data/Y_train.csv', index_col=0)

# Remove league and team name, we want to generalize the results
train_home = train_home_team_statistics_df.iloc[:,2:]
train_away = train_away_team_statistics_df.iloc[:,2:]

# Designate home and away columns
train_home.columns = 'HOME_' + train_home.columns
train_away.columns = 'AWAY_' + train_away.columns

# Concatenate home and away data
train_data =  pd.concat([train_home, train_away], join='inner', axis=1)
train_data = train_data.replace({np.inf:np.nan, -np.inf:np.nan})

# Revert combine home-win, draw, and away-win columns into one
train_labels = train_labels.loc[train_data.index]
train_labels = train_labels.values.tolist()

# %%
# Read test set
test_home = pd.read_csv('../Test_Data/test_home_team_statistics_df.csv', index_col=0)
test_away = pd.read_csv('../Test_Data/test_away_team_statistics_df.csv', index_col=0)

# Read public test labels
test_labels = pd.read_csv('../Test_Data/Y_test.csv', index_col=0)

# Change column names
test_home.columns = 'HOME_' + test_home.columns
test_away.columns = 'AWAY_' + test_away.columns

# Basic data cleaning
test_data =  pd.concat([test_home,test_away], join='inner', axis=1)
test_data = test_data.replace({np.inf:np.nan, -np.inf:np.nan})

# Revert combine home-win, draw, and away-win columns into one
test_labels = test_labels.loc[test_data.index]
test_labels = test_labels.values.tolist()

# %% [markdown]
# ## Problem Description
# The target score is the accuracy of prediction for the vector `[HOME_WINS, DRAW, AWAY_WINS]`, for which there are three possible choices, `[1,0,0]`, `[0,1,0]`, and `[0,0,1]`. The train-test split has been provided from the original problem data package.

# %%
# 80-20 Train and Test Split
X_train, X_test, y_train, y_test = train_data, test_data, train_labels, test_labels

# %% [markdown]
# ## Multi-Layer Perceptron Model

# %%
# Prepare data preprocessing pipeline
# Impute NaNs with mean, as the classifier can't handle missing inputs
# Use standard scaler, as recommended by the MLPClassifier documentation
numeric_transformer = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='median')),
    ('scale', StandardScaler())
  ])

# Create a column transformer with the previous steps
preprocessor = ColumnTransformer(
    transformers=[
         ('preprocess', numeric_transformer, X_train.columns)
    ])

# Create a pipeline object
PIPELINE = Pipeline(steps=[('preprocessor', preprocessor), ('estimator', MLPClassifier())])

# List for hyperparameter search
GRID = [
    {
     'estimator': [MLPClassifier(random_state=1)],
     'estimator__solver': ['adam'],
     'estimator__learning_rate_init': [0.0001],
     'estimator__max_iter': [300],
     'estimator__hidden_layer_sizes': [(5, 3, 2, 1)],
     'estimator__activation': ['relu', 'lbfgs'],
     'estimator__alpha': [0.1, 0.001, 0.0001, 0.00001],
     'estimator__early_stopping': [True]
     }
]

# Run grid search to look for the best parameters
grid_search = GridSearchCV(estimator=PIPELINE, param_grid=GRID, 
                            scoring="accuracy", 
                            n_jobs=-1, cv=10, refit=True, verbose=10, 
                            return_train_score=False)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# [CV 5/10; 1/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 2/10; 1/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 3/10; 1/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 7/10; 1/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 8/10; 1/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 1/10; 1/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 4/10; 1/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 6/10; 1/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 3/10; 1/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.469 total time=   6.7s
# [CV 5/10; 1/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.429 total time=   6.8s
# [CV 2/10; 1/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.446 total time=   6.8s
# [CV 9/10; 1/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 10/10; 1/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 1/10; 2/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 7/10; 1/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.466 total time=   6.8s
# [CV 6/10; 1/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.476 total time=   6.7s
# [CV 1/10; 1/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.439 total time=   6.8s
# [CV 2/10; 2/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 3/10; 2/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 4/10; 1/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.486 total time=   7.0s
# [CV 4/10; 2/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 5/10; 2/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 8/10; 1/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.456 total time=   7.3s
# [CV 6/10; 2/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 9/10; 1/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.466 total time=  10.6s
# [CV 7/10; 2/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 10/10; 1/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.457 total time=  10.6s
# [CV 8/10; 2/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 1/10; 2/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.438 total time=  10.8s
# [CV 9/10; 2/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 2/10; 2/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.446 total time=  10.7s
# [CV 5/10; 2/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.426 total time=  10.3s
# [CV 10/10; 2/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 1/10; 3/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 4/10; 2/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.486 total time=  11.2s
# [CV 2/10; 3/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 3/10; 2/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.467 total time=  11.3s
# [CV 3/10; 3/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 6/10; 2/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.473 total time=  11.2s
# [CV 4/10; 3/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 9/10; 2/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.463 total time=   6.4s
# [CV 5/10; 3/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 8/10; 2/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.458 total time=   6.5s
# [CV 10/10; 2/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.459 total time=   6.3s
# [CV 6/10; 3/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 7/10; 3/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 7/10; 2/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.467 total time=   6.8s
# [CV 8/10; 3/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 1/10; 3/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.439 total time=   6.6s
# [CV 9/10; 3/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 3/10; 3/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.468 total time=   6.4s
# [CV 10/10; 3/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 4/10; 3/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.487 total time=   6.6s
# [CV 2/10; 3/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.445 total time=   7.0s
# [CV 1/10; 4/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 2/10; 4/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 8/10; 3/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.458 total time=   6.6s
# [CV 3/10; 4/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 7/10; 3/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.468 total time=   6.9s
# [CV 4/10; 4/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 5/10; 3/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.429 total time=   7.1s
# [CV 5/10; 4/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 9/10; 3/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.464 total time=   6.8s
# [CV 6/10; 3/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.475 total time=   7.2s
# [CV 7/10; 4/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 6/10; 4/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 10/10; 3/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.459 total time=   6.6s
# [CV 8/10; 4/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 2/10; 4/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.442 total time=   6.3s
# [CV 1/10; 4/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.437 total time=   6.4s
# [CV 9/10; 4/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 10/10; 4/8] START estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 5/10; 4/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.428 total time=   5.5s
# [CV 3/10; 4/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.468 total time=   5.8s
# [CV 1/10; 5/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 2/10; 5/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 6/10; 4/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.475 total time=   5.5s
# [CV 4/10; 4/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.486 total time=   5.8s
# [CV 3/10; 5/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 4/10; 5/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 7/10; 4/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.469 total time=   6.0s
# [CV 5/10; 5/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 8/10; 4/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.458 total time=   5.8s
# [CV 6/10; 5/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 10/10; 4/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.459 total time=   5.6s
# [CV 7/10; 5/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 9/10; 4/8] END estimator=MLPClassifier(random_state=1), estimator__activation=relu, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=0.463 total time=   5.9s
# [CV 8/10; 5/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 1/10; 5/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.2s
# [CV 9/10; 5/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 3/10; 5/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.2s
# [CV 10/10; 5/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 2/10; 5/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.4s
# [CV 1/10; 6/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 4/10; 5/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.4s
# [CV 2/10; 6/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 5/10; 5/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.3s
# [CV 3/10; 6/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 6/10; 5/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.3s
# [CV 4/10; 6/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 7/10; 5/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.3s
# [CV 5/10; 6/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 8/10; 5/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.4s
# [CV 6/10; 6/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 9/10; 5/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.3s
# [CV 7/10; 6/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 1/10; 6/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.2s
# [CV 10/10; 5/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.1, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.4s
# [CV 9/10; 6/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 8/10; 6/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 2/10; 6/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.3s
# [CV 10/10; 6/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 3/10; 6/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.1s
# [CV 1/10; 7/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 4/10; 6/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.3s
# [CV 2/10; 7/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 5/10; 6/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.4s
# [CV 3/10; 7/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 6/10; 6/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.4s
# [CV 4/10; 7/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 9/10; 6/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.2s
# [CV 5/10; 7/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 8/10; 6/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.2s
# [CV 6/10; 7/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 7/10; 6/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.5s
# [CV 7/10; 7/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 10/10; 6/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.4s
# [CV 8/10; 7/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 1/10; 7/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.2s
# [CV 9/10; 7/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 2/10; 7/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.3s
# [CV 3/10; 7/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.3s
# [CV 10/10; 7/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 1/10; 8/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 4/10; 7/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.4s
# [CV 2/10; 8/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 5/10; 7/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.4s
# [CV 6/10; 7/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.5s
# [CV 4/10; 8/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 3/10; 8/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 7/10; 7/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.5s
# [CV 5/10; 8/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 8/10; 7/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.5s
# [CV 6/10; 8/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 9/10; 7/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.7s
# [CV 7/10; 8/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 10/10; 7/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=0.0001, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.5s
# [CV 1/10; 8/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.5s
# [CV 8/10; 8/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 9/10; 8/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 2/10; 8/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.6s
# [CV 10/10; 8/8] START estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam
# [CV 3/10; 8/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.3s
# [CV 4/10; 8/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.4s
# [CV 5/10; 8/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.5s
# [CV 6/10; 8/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.4s
# [CV 7/10; 8/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.2s
# [CV 9/10; 8/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.1s
# [CV 8/10; 8/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   1.1s
# [CV 10/10; 8/8] END estimator=MLPClassifier(random_state=1), estimator__activation=lbfgs, estimator__alpha=1e-05, estimator__early_stopping=True, estimator__hidden_layer_sizes=(5, 3, 2, 1), estimator__learning_rate_init=0.0001, estimator__max_iter=300, estimator__solver=adam;, score=nan total time=   0.8s
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('preprocess',
#                                                                          Pipeline(steps=[('impute',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scale',
#                                                                                           StandardScaler())]),
#                                                                          Index(['HOME_TEAM_SHOTS_TOTAL_season_sum',
#        'HOME_TEAM_SHOTS_INSIDEBOX_season_sum',
#        'HOME_TEAM_SHOTS_OFF_TARGET_season_sum',
#        'HOME_TEAM_SHOTS_ON_TARGET_season...
#              param_grid=[{'estimator': [MLPClassifier(random_state=1)],
#                           'estimator__activation': ['relu', 'lbfgs'],
#                           'estimator__alpha': [0.1, 0.001, 0.0001, 1e-05],
#                           'estimator__early_stopping': [True],
#                           'estimator__hidden_layer_sizes': [(5, 3, 2, 1)],
#                           'estimator__learning_rate_init': [0.0001],
#                           'estimator__max_iter': [300],
#                           'estimator__solver': ['adam']}],
#              scoring='accuracy', verbose=10)

# %% [markdown]
# ## Accuracy on Test Set

# %%
print(f"The accuracy of the model is {grid_search.score(X_test, y_test)}")
print(grid_search.best_params_)
# Out:
# The accuracy of the model is 0.33660517187007255
# {'estimator': MLPClassifier(random_state=1), 'estimator__activation': 'relu', 'estimator__alpha': 0.0001, 'estimator__early_stopping': True, 'estimator__hidden_layer_sizes': (5, 3, 2, 1), 'estimator__learning_rate_init': 0.0001, 'estimator__max_iter': 300, 'estimator__solver': 'adam'}

# %% [markdown]
# ## Submission

# %%
# Make predictions, ordered by row
submission = pd.DataFrame(grid_search.predict(X_test))
submission = submission.rename(columns={0: 'HOME_WINS', 1: 'DRAW', 2: 'AWAY_WINS'})
submission.index = X_test.index

# Save the submission file
submission.to_csv('./submission.csv', index=True)
